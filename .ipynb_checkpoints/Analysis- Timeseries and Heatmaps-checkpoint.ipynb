# %%
# %matplotlib inline
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
import gmplot
import gmaps
from IPython.core.display import display, HTML

# %%
df = pd.read_pickle('master_location.pkl')
df_crime = pd.read_pickle('crime.pkl')

# %%
diff = df.tail(1).iloc[0]['date'] - df.head(1).iloc[0]['date']
print('Range of data: {}'.format(diff))
diff = df_crime.tail(1).iloc[0]['date'] - df_crime.head(1).iloc[0]['date']
print('Range of data: {}'.format(diff))
# Out:
# Range of data: 28 days 01:28:44
# Range of data: 274 days 11:46:00

# %%
# df['hour'] = df.date.apply(lambda d: d.hour) 
# df['dayofweek'] = df.date.apply(lambda d: d.dayofweek)
# df['dayofweek_name'] = df.date.apply(lambda d: d.weekday_name)
# df['day'] = df.date.apply(lambda d: d.day)
# df['count'] = 1
# df.to_pickle('master_location.pkl')

# %%
types = set(df.type)
print('Types of Accidents: {}'.format(types))
loc = set(df.area)
print('Locations of Accidents: {}'.format(loc))
df.head()
# Out:
# Types of Accidents: {'TRAFFIC NUISANCE OR PARKING VIOLATION', 'TRAFFIC SIGNAL PROBLEM', 'TRAFFIC INCIDENT - NO COLLISION', 'MOTOR VEHICLE COLLISION', 'MOTOR VEHICLE COLLISION - TOWED', 'HAZARDOUS DRIVER', 'STALLED/HAZARDOUS VEHICLE'}
# Locations of Accidents: {'SCHOFIELD', 'BELLOWS', 'SUNSET', 'HAUULA', 'WAIPAHU', 'KAKAAKO', 'NUUANU', 'WAIANAE', 'LAIE', 'KAHALA', 'FT DERUSSY', 'WAIKIKI', 'PEARL HBR', 'MANOA', 'MILILANI', 'KALIHI', 'WAIALAE', 'EWA BEACH', 'KAPOLEI', 'AIRPORT', 'HOKULANI', 'MAKAKILO', 'DOWNTOWN', 'HICKAM', 'KALAELOA', 'MAILI', 'MAPUNAPUNA', 'PC PEN', 'PEARL CITY', 'MOANALUA T', 'KAHUKU', 'HAWAII KAI', 'KAHALUU', 'AMR', 'WAIALUA', 'ALIAMANU', 'TRIPLER', 'MOANALUA', 'WAHIAWA', 'WAIPIO', '\xa0', 'MAKIKI', 'HALEIWA', 'AINA HAINA', 'NANAKULI', 'KAPAHULU', 'MCBH', 'KAILUA', 'KUNIA', 'KAAAWA', 'MAKAHA', 'HONOLULU', 'IROQUOIS', 'AIEA', 'RADFORD T', 'MOANALUA V', 'HALE MOKU', 'KAIMUKI', 'WAIMANALO', 'KANEOHE', 'MOKULEIA', 'MCCULLY', 'ALA MOANA', 'PUNALUU', 'PUNCHBOWL', 'SALT LAKE'}
#                      address      area  count                date  day  \
# 4333        174X MAHANI LOOP    KALIHI      1 2016-11-07 16:51:13    7
# 4332  KAWAIAHAO ST&SOUTH; ST  HONOLULU      1 2016-11-07 16:54:37    7
# 4331        316X HARDING AVE   KAIMUKI      1 2016-11-07 16:56:45    7
# 4330   KILAUEA AVE&MALIA; ST   WAIALAE      1 2016-11-07 17:02:02    7
# 4329         H2N WAHIAWA OFF  MILILANI      1 2016-11-07 17:03:05    7
#
#       dayofweek dayofweek_name  hour   latitude         location   longitude  \
# 4333          0         Monday    16  21.351571                  -157.857829
# 4332          0         Monday    16  21.302850                  -157.857111
# 4331          0         Monday    16  21.286176                  -157.809424
# 4330          0         Monday    17  21.280513                  -157.784640
# 4329          0         Monday    17  21.472379  H2N WAHIAWA OFF -158.010142
#
#             time                                   type
# 4333  4:51:13 PM                MOTOR VEHICLE COLLISION
# 4332  4:54:37 PM        MOTOR VEHICLE COLLISION - TOWED
# 4331  4:56:45 PM                MOTOR VEHICLE COLLISION
# 4330  5:02:02 PM                MOTOR VEHICLE COLLISION
# 4329  5:03:05 PM  TRAFFIC NUISANCE OR PARKING VIOLATION

# %%
df['day'] = df.date.apply(lambda d: d.day)
df.sort_values('date').tail()
# Out:
#                           address        area  count                date  day  \
# 231   W HIND DR&KALANIANAOLE; HWY  AINA HAINA      1 2016-12-05 18:07:57    5
# 230   E HIND DR&KALANIANAOLE; HWY  AINA HAINA      1 2016-12-05 18:08:45    5
# 229             VINEYARD ONTO H1E    HONOLULU      1 2016-12-05 18:08:57    5
# 228  KE ALA MANO ST&MAKUAKANE; ST      KALIHI      1 2016-12-05 18:10:20    5
# 227               94105X NALII ST     WAIPAHU      1 2016-12-05 18:19:57    5
#
#      dayofweek dayofweek_name  hour   latitude           location   longitude  \
# 231          0         Monday    18  21.277883                    -157.755145
# 230          0         Monday    18  21.278681                    -157.749133
# 229          0         Monday    18        NaN  VINEYARD ONTO H1E         NaN
# 228          0         Monday    18  21.339239                    -157.866102
# 227          0         Monday    18  21.390273                    -158.001856
#
#            time                       type
# 231  6:07:57 PM  STALLED/HAZARDOUS VEHICLE
# 230  6:08:45 PM  STALLED/HAZARDOUS VEHICLE
# 229  6:08:57 PM    MOTOR VEHICLE COLLISION
# 228  6:10:20 PM    MOTOR VEHICLE COLLISION
# 227  6:19:57 PM    MOTOR VEHICLE COLLISION

# %%
# day_groups = df['exact_date'].value_counts().sort_index().plot(kind='line')
# df['exact_date'] = df['date'].apply(lambda d: d.)
mapping_type = {'HAZARDOUS DRIVER':'Hazardous Driver', 
                'STALLED/HAZARDOUS VEHICLE':'Stalled or Hazardous Vehicle', 
                'TRAFFIC INCIDENT - NO COLLISION':'Traffic Incident with No Collision', 
                'TRAFFIC NUISANCE OR PARKING VIOLATION':'Traffic Nuisance or Parking Violation', 
                'MOTOR VEHICLE COLLISION':'Motor Vehicle Collision', 
                'TRAFFIC SIGNAL PROBLEM':'Traffic Signaling Issue', 
                'MOTOR VEHICLE COLLISION - TOWED':'Motor Vehicle Collision: Towed'}

df['short_date'] = df['date'].apply(lambda x:x.date().strftime('%m/%d/%y'))
groups = df.groupby('type')
names = []
for name, group in groups:
    group.short_date.value_counts().sort_index().plot(kind='line', legend=True, figsize=(10,7))
    names.append(name)
plt.ylim(0, 175)
plt.title('Frequency of Traffic Incidents by Day')
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.legend(['Hazardous Driver','Motor Vehicle Collision','Motor Vehicle Collision- Towed','Stalled/Hazardous Vehicle','Traffic Incident- No Collision','Traffic Nuisance or Parking Violation','Traffic Signal Problem'], title = 'Incident Type', loc='upper right',prop={'size':7})
# plt.subplots_adjust(right=0.8)
plt.savefig('graphs/traffic_frequency.png')
# df.loc['MOTOR VEHICLE COLLISION']['short_date'].value_counts().sort_index().plot(kind='line')

# %%
t = ['HAZARDOUS DRIVER', 'STALLED/HAZARDOUS VEHICLE', 'TRAFFIC INCIDENT - NO COLLISION', 'TRAFFIC NUISANCE OR PARKING VIOLATION', 
                'MOTOR VEHICLE COLLISION', 'TRAFFIC SIGNAL PROBLEM', 'MOTOR VEHICLE COLLISION - TOWED']
df_area = df.groupby(['area']).filter(lambda x: len(x) >= 10)
# df_area['count'] = 1
groups = df_area[['area','type','count']].groupby(['area','type']).count().unstack()
groups['total'] = groups.sum(axis=1)
groups = groups.sort_values('total', ascending=False)
groups = groups.drop('total', axis=1)
groups.plot.bar(stacked = True, figsize=(10,6))
groups =  groups.sortlevel(axis=1, level=0)
plt.legend(['Hazardous Driver','Motor Vehicle Collision','Motor Vehicle Collision- Towed','Stalled/Hazardous Vehicle','Traffic Incident- No Collision','Traffic Nuisance or Parking Violation','Traffic Signal Problem'], title = 'Incident Type' ,prop={'size':9})
plt.title('Traffic Inicdent Types by Area')
plt.ylim(0,505)
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.savefig('graphs/traffic_area.png')
# groups = df_area.area.value_counts()
# groups.plot(kind='bar', stacked=True, figsize=(12,10))
# for name, group in groups:
#     group.
#     group['type'].value_counts().sort_index().plot(kind='bar', legend=True, figsize=(12,10))
# df_area.ar.plot(kind='bar',figsize=(12,10))

# %%
t = ['HAZARDOUS DRIVER', 'STALLED/HAZARDOUS VEHICLE', 'TRAFFIC INCIDENT - NO COLLISION', 'TRAFFIC NUISANCE OR PARKING VIOLATION', 
                'MOTOR VEHICLE COLLISION', 'TRAFFIC SIGNAL PROBLEM', 'MOTOR VEHICLE COLLISION - TOWED']
df_area = df.groupby(['area']).filter(lambda x: len(x) >= 10)
# df_area['count'] = 1
groups = df_area[['area','type','count']].groupby(['area','type']).count().unstack()
groups['total'] = groups.sum(axis=1)
groups = groups.sort_values('total', ascending=False)
groups = groups.drop('total', axis=1)
groups.plot.bar(stacked = True, figsize=(10,6))
groups =  groups.sortlevel(axis=1, level=0)
plt.legend(['Hazardous Driver','Motor Vehicle Collision','Motor Vehicle Collision- Towed','Stalled/Hazardous Vehicle','Traffic Incident- No Collision','Traffic Nuisance or Parking Violation','Traffic Signal Problem'], title = 'Incident Type' ,prop={'size':9})
plt.title('Traffic Inicdent Types by Area')
plt.ylim(0,505)
plt.xlabel('Area')
plt.ylabel('Frequency')
plt.savefig('graphs/traffic_area.png')

# %%
'''Traffic Incident frequency by day of the week'''
mapping_day = {
        '0':'Monday',
        '1':'Tuesday',
        '2':'Wednesday',
        '3':'Thursday',
        '4':'Friday',
        '5':'Saturday',
        '6':'Sunday'
}

mapping_type = {'HAZARDOUS DRIVER':'Hazardous Driver', 
                'STALLED/HAZARDOUS VEHICLE':'Stalled or Hazardous Vehicle', 
                'TRAFFIC INCIDENT - NO COLLISION':'Traffic Incident with No Collision', 
                'TRAFFIC NUISANCE OR PARKING VIOLATION':'Traffic Nuisance or Parking Violation', 
                'MOTOR VEHICLE COLLISION':'Motor Vehicle Collision', 
                'TRAFFIC SIGNAL PROBLEM':'Traffic Signaling Issue', 
                'MOTOR VEHICLE COLLISION - TOWED':'Motor Vehicle Collision: Towed'}
collisionTypes = df[['type','latitude','longitude','hour','dayofweek', 'dayofweek_name','day','count']].groupby(['type','dayofweek']).count()
collisionTypes
for t in mapping_type:
    ax = collisionTypes.loc[t][['count']].plot.bar(title = 'Frequency of ' + mapping_type[t] + 's by Day of The Week', legend = False, rot = 0, figsize=(8,6), width=0.75)
    days = [item.get_text() for item in ax.get_xticklabels()]
    labels = [mapping_day[day] for day in days]
    ax.set_xticklabels(labels)
    ax.set_xlabel('Day of the Week')
    ax.set_ylabel('Frequency')
    ax.set_ylim(None, max(collisionTypes.loc[t][['count']].values) + 5)
    ax.yaxis.grid(True)
    fig = ax.get_figure()
    fig.savefig('graphs/dayofweek_' + mapping_type[t].replace(' ','') +'.png')

# %%
'''Traffic incident frequency by hour of the day'''
collisionTypes = df[['type','latitude','longitude','hour','dayofweek', 'dayofweek_name','day','count']].groupby(['type','hour']).count()
collisionTypes
for t in mapping_type:
    ax = collisionTypes.loc[t][['count']].plot.bar(title = 'Frequency of ' + mapping_type[t] + ' by Hour of the Day', legend = False, rot = 0, figsize=(8,6), width=0.75)
    days = [item.get_text() for item in ax.get_xticklabels()]
#     labels = [mapping_day[day] for day in days]
#     ax.set_xticklabels(labels)
    ax.set_xlabel('Hour of the Day')
    ax.set_ylabel('Frequency')
    ax.set_ylim(None, max(collisionTypes.loc[t][['count']].values) + 5)
    ax.yaxis.grid(True)
    fig = ax.get_figure()
    fig.savefig('graphs/hourofday_' + mapping_type[t].replace(' ','') +'.png')

# %%
'''Crime incidents by day of the week'''
mapping_day = {
        '0':'Monday',
        '1':'Tuesday',
        '2':'Wednesday',
        '3':'Thursday',
        '4':'Friday',
        '5':'Saturday',
        '6':'Sunday'
}

mapping_type = {'BURGLARY': 'Burglary',
                 'MOTOR VEHICLE THEFT': 'Motor Vehicle Theft',
                 'THEFT/LARCENY': 'Theft or Larcey',
                 'VANDALISM': 'Vandalism',
                 'VEHICLE BREAK-IN/THEFT': 'Vehicle Break In or Theft'}
crimeTypes = df_crime[['Type','hour','dayofweek', 'dayofweek_name','day','count']].groupby(['Type','dayofweek']).count()
for t in mapping_type:
    ax = crimeTypes.loc[t][['count']].plot.bar(title = 'Frequency of ' + mapping_type[t] + 's by Day of The Week', legend = False, rot = 0, figsize=(8,6), width=0.75)
    days = [item.get_text() for item in ax.get_xticklabels()]
    labels = [mapping_day[day] for day in days]
    ax.set_xticklabels(labels)
    ax.set_xlabel('Day of the Week')
    ax.set_ylabel('Frequency')
    max_val = max(crimeTypes.loc[t][['count']].values)
    ax.set_ylim(None, max_val*1.05)
    ax.yaxis.grid(True)
    fig = ax.get_figure()
    fig.savefig('graphs/dayofweek_' + mapping_type[t].replace(' ','') +'.png')

# %%
df_crime.head()
# Out:
#    ObjectID          KiloNBR                BlockAddress  \
# 0    583660  LHP151117000412          H3W HALAWA VLY  UP
# 1    583719  LHP151117001422  HOLOMOANA ST&KAHANAMOKU ST
# 2    584226  LHP151118000054        2600 BLOCK GORDON ST
# 3    584261  LHP151118000541             0 BLOCK H2N FWY
# 4    584273  LHP151118000642     4400 BLOCK KAPOLEI PKWY
#
#                                  CMID         CMAgency  \
# 0  Honolulu_PD_HI_LHP151117000412_077  Honolulu PD, HI
# 1  Honolulu_PD_HI_LHP151117001422_064  Honolulu PD, HI
# 2  Honolulu_PD_HI_LHP151118000054_077  Honolulu PD, HI
# 3  Honolulu_PD_HI_LHP151118000541_060  Honolulu PD, HI
# 4  Honolulu_PD_HI_LHP151118000642_060  Honolulu PD, HI
#
#                      Type Status  Score Side  hour  dayofweek dayofweek_name  \
# 0     MOTOR VEHICLE THEFT      U      0  NaN    18          1        Tuesday
# 1  VEHICLE BREAK-IN/THEFT      U      0  NaN     3          2      Wednesday
# 2     MOTOR VEHICLE THEFT      U      0  NaN    11          2      Wednesday
# 3           THEFT/LARCENY      U      0  NaN    19          2      Wednesday
# 4           THEFT/LARCENY      U      0  NaN    20          2      Wednesday
#
#    day  count                date
# 0   17      1 2015-11-17 18:34:00
# 1   18      1 2015-11-18 03:40:00
# 2   18      1 2015-11-18 11:21:00
# 3   18      1 2015-11-18 19:43:00
# 4   18      1 2015-11-18 20:57:00

# %%
'''Crime incidents by hour of the day'''
crimeTypes = df_crime[['Type','hour','dayofweek', 'dayofweek_name','day','count']].groupby(['Type','hour']).count()
for t in mapping_type:
    ax = crimeTypes.loc[t][['count']].plot.bar(title = 'Frequency of ' + mapping_type[t] + ' by Hour of the Day', legend = False, rot = 0, figsize=(8,6), width=0.75)
    days = [item.get_text() for item in ax.get_xticklabels()]
    ax.set_xlabel('Hour of the Day')
    ax.set_ylabel('Frequency')
    max_val = max(crimeTypes.loc[t][['count']].values) * 1.05
    ax.set_ylim(None, max_val)
    ax.yaxis.grid(True)
    fig = ax.get_figure()
    fig.savefig('graphs/hourofday_' + mapping_type[t].replace(' ','') +'.png')

# %%
'''Generate list of latitude and logitude data'''
# df.index.get_level_values(0).get_duplicates() # Finding duplicate rows 
temp = df.reset_index().drop_duplicates(subset='index',keep='last').set_index('index')
lat_dict = temp.latitude.to_dict()
lon_dict = temp.longitude.to_dict()
keys = lat_dict.keys()
lat_list = []
lon_list = []
for key in keys:
    lat_list.append(lat_dict[key])
    lon_list.append(lon_dict[key])

# %%
'''One library that creates renders a map in an HTML file #not using'''
# gmap = gmplot.GoogleMapPlotter(21.45, -157.97, 11)
# gmap.scatter(lat_list, lon_list)
# gmap.heatmap(lat_list, lon_list)
# Out:
# 'One library that creates renders a map in an HTML file #not using'

# %%
'''Generate latitude and longitude data as tuples in a list'''
data = [(lat_dict[key], lon_dict[key]) for key in lat_dict if not np.isnan(lat_dict[key]) ]

# %%
gmaps.configure(api_key='AIzaSyCmr-ah82Xzb6uq2jOLlIFgek_CI7Mg4Uw')

# %%
m = gmaps.Map()
heatmap_layer = gmaps.Heatmap(data = data)
heatmap_layer.max_intensity = 100 
heatmap_layer.point_radius = 10
heatmap_layer.opacity = 1


# markers = gmaps.symbol_layer(data, fill_color='red', stroke_color='red', scale=2)
# m.add_layer(markers)
m.add_layer(heatmap_layer)
m

# %%
import folium 
from folium import plugins

heatmap = folium.Map(location=[21.45, -157.97], zoom_start=11)
heatmap.add_children(plugins.HeatMap([[coord[0],coord[1]] for coord in data]))
heatmap.
heatmap.save('heatmap.html')
