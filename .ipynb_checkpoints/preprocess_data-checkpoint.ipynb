# %% [markdown]
# # Preprocessing Scraped Data
#
# Web scraper is currently running on csa2. Data files represent data scraped every hour from the Honolulu HPD [website](http://www4.honolulu.gov/hpdtraffic/MainPrograms/frmMain.asp?sSearch=All+Incidents&sSort=I_tTimeCreate)

# %%
# %matplotlib inline
import json
import pandas as pd
import os
import googlemaps
import json
import sys  
import matplotlib.pyplot as plt

# %%
# Convert data files into a Pandas Data Frame
file_names = []
for file in os.listdir('data/'):
    file_names.append(file)

data_master = []
for file in file_names:
    with open('data/' + file, 'r') as f:
        data = json.loads(f.readline())
        data_master = data_master + data
        
df_master = pd.DataFrame(data_master)
df_master.to_csv('master_dataset.csv')  
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4479 entries, 0 to 4478
# Data columns (total 6 columns):
# address     4479 non-null object
# area        4479 non-null object
# date        4479 non-null object
# location    4479 non-null object
# time        4479 non-null object
# type        4479 non-null object
# dtypes: object(6)
# memory usage: 210.0+ KB

# %%
# Read csv, combine "date" and "time" column to a date object, and sort by "date" column
df = pd.read_csv('master_dataset.csv', index_col='Unnamed: 0')
# df = df_master
df['date'] = df['date'].astype(str) + ' ' + df['time']
df['date'] = pd.to_datetime(df['date'])
df = df.sort_values(by='date')
df.head()
# Out:
#                      address      area                date         location  \
# 4333        174X MAHANI LOOP    KALIHI 2016-11-07 16:51:13
# 4332  KAWAIAHAO ST&SOUTH; ST  HONOLULU 2016-11-07 16:54:37
# 4331        316X HARDING AVE   KAIMUKI 2016-11-07 16:56:45
# 4330   KILAUEA AVE&MALIA; ST   WAIALAE 2016-11-07 17:02:02
# 4329         H2N WAHIAWA OFF  MILILANI 2016-11-07 17:03:05  H2N WAHIAWA OFF
#
#             time                                   type
# 4333  4:51:13 PM                MOTOR VEHICLE COLLISION
# 4332  4:54:37 PM        MOTOR VEHICLE COLLISION - TOWED
# 4331  4:56:45 PM                MOTOR VEHICLE COLLISION
# 4330  5:02:02 PM                MOTOR VEHICLE COLLISION
# 4329  5:03:05 PM  TRAFFIC NUISANCE OR PARKING VIOLATION

# %%
# Initialize Google Maps 
api_key = 'AIzaSyCmr-ah82Xzb6uq2jOLlIFgek_CI7Mg4Uw'
gmaps = googlemaps.Client(key=api_key)

# %%
# Example calls to Google Maps of highways, highway offramps, and street intersections
result = gmaps.geocode('H2N WAHIAWA OFF, MILILANI, HI')
print(json.dumps(result, indent=4))
result = gmaps.geocode('INTERSTATE H-2, WAHIAWA, HI')  #This actually gives back the right location
print(json.dumps(result, indent=4))
result = gmaps.geocode('KAWAIAHAO ST & SOUTH ST, HONOLULU, HI')
print(json.dumps(result, indent=4))
# Out:
# [
#     {
#         "geometry": {
#             "location_type": "APPROXIMATE",
#             "bounds": {
#                 "southwest": {
#                     "lat": 21.4262321,
#                     "lng": -158.0301801
#                 },
#                 "northeast": {
#                     "lat": 21.4658301,
#                     "lng": -157.9924
#                 }
#             },
#             "viewport": {
#                 "southwest": {
#                     "lat": 21.4262321,
#                     "lng": -158.0301801
#                 },
#                 "northeast": {
#                     "lat": 21.4658301,
#                     "lng": -157.9924
#                 }
#             },
#             "location": {
#                 "lat": 21.4513314,
#                 "lng": -158.0152807
#             }
#         },
#         "address_components": [
#             {
#                 "types": [
#                     "locality",
#                     "political"
#                 ],
#                 "short_name": "Mililani",
#                 "long_name": "Mililani"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ],
#                 "short_name": "Honolulu County",
#                 "long_name": "Honolulu County"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ],
#                 "short_name": "HI",
#                 "long_name": "Hawaii"
#             },
#             {
#                 "types": [
#                     "country",
#                     "political"
#                 ],
#                 "short_name": "US",
#                 "long_name": "United States"
#             },
#             {
#                 "types": [
#                     "postal_code"
#                 ],
#                 "short_name": "96789",
#                 "long_name": "96789"
#             }
#         ],
#         "formatted_address": "Mililani, HI 96789, USA",
#         "partial_match": true,
#         "place_id": "ChIJ_cVNtwRnAHwRFaLS4aRQi7Y",
#         "types": [
#             "locality",
#             "political"
#         ]
#     }
# ]
# [
#     {
#         "geometry": {
#             "location_type": "GEOMETRIC_CENTER",
#             "bounds": {
#                 "southwest": {
#                     "lat": 21.4873361,
#                     "lng": -158.0318715
#                 },
#                 "northeast": {
#                     "lat": 21.4906119,
#                     "lng": -158.0258066
#                 }
#             },
#             "viewport": {
#                 "southwest": {
#                     "lat": 21.4873361,
#                     "lng": -158.0318715
#                 },
#                 "northeast": {
#                     "lat": 21.4906119,
#                     "lng": -158.0258066
#                 }
#             },
#             "location": {
#                 "lat": 21.4899017,
#                 "lng": -158.0283554
#             }
#         },
#         "address_components": [
#             {
#                 "types": [
#                     "route"
#                 ],
#                 "short_name": "I-H-2",
#                 "long_name": "Interstate H-2"
#             },
#             {
#                 "types": [
#                     "locality",
#                     "political"
#                 ],
#                 "short_name": "Wahiawa",
#                 "long_name": "Wahiawa"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ],
#                 "short_name": "Honolulu County",
#                 "long_name": "Honolulu County"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ],
#                 "short_name": "HI",
#                 "long_name": "Hawaii"
#             },
#             {
#                 "types": [
#                     "country",
#                     "political"
#                 ],
#                 "short_name": "US",
#                 "long_name": "United States"
#             },
#             {
#                 "types": [
#                     "postal_code"
#                 ],
#                 "short_name": "96786",
#                 "long_name": "96786"
#             }
#         ],
#         "formatted_address": "I-H-2, Wahiawa, HI 96786, USA",
#         "types": [
#             "route"
#         ],
#         "place_id": "ChIJu1b5swNnAHwRKmo9ACZNvQc"
#     }
# ]
# [
#     {
#         "geometry": {
#             "location_type": "APPROXIMATE",
#             "viewport": {
#                 "southwest": {
#                     "lat": 21.3015011197085,
#                     "lng": -157.8584594802915
#                 },
#                 "northeast": {
#                     "lat": 21.3041990802915,
#                     "lng": -157.8557615197085
#                 }
#             },
#             "location": {
#                 "lat": 21.3028501,
#                 "lng": -157.8571105
#             }
#         },
#         "address_components": [
#             {
#                 "types": [
#                     "route"
#                 ],
#                 "short_name": "Kawaiahao St",
#                 "long_name": "Kawaiahao Street"
#             },
#             {
#                 "types": [
#                     "neighborhood",
#                     "political"
#                 ],
#                 "short_name": "Downtown",
#                 "long_name": "Downtown"
#             },
#             {
#                 "types": [
#                     "locality",
#                     "political"
#                 ],
#                 "short_name": "Honolulu",
#                 "long_name": "Honolulu"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_2",
#                     "political"
#                 ],
#                 "short_name": "Honolulu County",
#                 "long_name": "Honolulu County"
#             },
#             {
#                 "types": [
#                     "administrative_area_level_1",
#                     "political"
#                 ],
#                 "short_name": "HI",
#                 "long_name": "Hawaii"
#             },
#             {
#                 "types": [
#                     "country",
#                     "political"
#                 ],
#                 "short_name": "US",
#                 "long_name": "United States"
#             },
#             {
#                 "types": [
#                     "postal_code"
#                 ],
#                 "short_name": "96813",
#                 "long_name": "96813"
#             }
#         ],
#         "formatted_address": "Kawaiahao St & South St, Honolulu, HI 96813, USA",
#         "types": [
#             "intersection"
#         ],
#         "place_id": "EjBLYXdhaWFoYW8gU3QgJiBTb3V0aCBTdCwgSG9ub2x1bHUsIEhJIDk2ODEzLCBVU0E"
#     }
# ]

# %%
# Store longitude and latitude data returned from Google Maps to dataframe 
df_temp = df.head(2300)
# List of dictionaries
d = []
errors = []
# Counter for how many datapoints have been processed
count = 0
for idx, row in df_temp.iterrows():
    count += 1
    try :
        change = row['address'].split(' ')
        for i in range(len(change)):
            if change[i][-1] == 'X':
                change[i] = change[i][:-1] + '0'
            if change[i].find('&') != -1:
                toDelete = change[i].find('&')
                change[i] = change[i][:toDelete] + ' & ' + change[i][toDelete+1:]
            if change[i].find('/') != -1:
                toDelete = change[i].find('/')
                change[i] = change[i][:toDelete] + ' & ' + change[i][toDelete+1:] + ' ST'
            if change[i].find(';') != -1:
                toDelete = change[i].find(';')
                change[i] = change[i][:toDelete] + '' + change[i][toDelete+1:]
        if change[0] == 'KAM':
            change[0] = 'KAMEHAMEHA HWY'
        if change[0][0] == 'H' and len(change[0]) == 3:
            change[0] = 'INTERSTATE H-' + change[0][1]
            if len(change) > 1:
                if change[2] == 'OFF' or change[2] == 'ON' or change[2] == 'FWY':
                    del change[2]

        elif len(change) > 1 and change[1][0] == 'H' and len(change[1]) == 3:
            change[1] = 'INTERSTATE H-' + change[1][1]
            if change[2] == 'OFF' or change[2] == 'ON' or change[2] == 'FWY':
                del change[2]
            del change[0]


        # Convert street, city, and state to a string representation
        add = ' '.join(change)
        address = [add, row['area'], 'HI'] #add=row['address']
        if address[1] == 'AIRPORT':
            if address[0] == 'INTERSTATE H-1':
                address[0] = '300 ROGERS BLVD'
            address[1] = 'HONOLULU'
        if address[1] == 'HOKULANI' or address[1] == 'DOWNTOWN' or address[1] == '':
            address[1] = 'HONOLULU'
        if address[1] == 'SUNSET':
            del address[1]
        if address[1] == 'MOANALUA V':
            address[1] = 'MOANALUA FWY'
            del address[0]

        address = ', '.join(address)
        result = gmaps.geocode(address)
    
        # Create a dictionary from results
        loc = result[0]['geometry']['location']
        point = {'index': idx, 'latitude':loc['lat'], 'longitude':loc['lng']}
        d.append(point)
        
        # Pickles a dataframe every 100 iteration so that we don't lose data if an error occurs
        if count % 100 == 0 or count == len(df):
            print('Iteration {}'.format(count))
            df_loc = pd.DataFrame(d)
            df_loc.to_pickle('location.pkl')
    except KeyboardInterrupt:
        print('Exiting...')
        try:
            sys.exit(0)
        except SystemExit:
            os._exit(0)
    except: 
        errors.append(idx)
#         print('Error: ' + str(address) + ' at index ' + str(idx))
        continue
# Out:
# Iteration 100
# Iteration 200
# Iteration 300
# Iteration 400
# Iteration 500
# Iteration 600
# Iteration 700
# Iteration 800
# Iteration 900
# Iteration 1000
# Iteration 1100
# Iteration 1200
# Iteration 1300
# Iteration 1400
# Iteration 1500
# Iteration 1600
# Iteration 1700
# Iteration 1800
# Iteration 1900
# Iteration 2000
# Iteration 2100
# Iteration 2200

# %%
df_loc = pd.read_pickle('location.pkl')
df_loc = df_loc.set_index('index')
df_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 4333 to 1481
# Data columns (total 2 columns):
# latitude     2175 non-null float64
# longitude    2175 non-null float64
# dtypes: float64(2)
# memory usage: 51.0 KB

# %%
df_subset = df.head(len(df_loc))
df_subset = df_subset.join(df_loc)
df_subset.head()
# Out:
#                      address      area                date         location  \
# 4333        174X MAHANI LOOP    KALIHI 2016-11-07 16:51:13
# 4332  KAWAIAHAO ST&SOUTH; ST  HONOLULU 2016-11-07 16:54:37
# 4331        316X HARDING AVE   KAIMUKI 2016-11-07 16:56:45
# 4330   KILAUEA AVE&MALIA; ST   WAIALAE 2016-11-07 17:02:02
# 4329         H2N WAHIAWA OFF  MILILANI 2016-11-07 17:03:05  H2N WAHIAWA OFF
#
#             time                                   type   latitude   longitude
# 4333  4:51:13 PM                MOTOR VEHICLE COLLISION  21.351571 -157.857829
# 4332  4:54:37 PM        MOTOR VEHICLE COLLISION - TOWED  21.302850 -157.857111
# 4331  4:56:45 PM                MOTOR VEHICLE COLLISION  21.286176 -157.809424
# 4330  5:02:02 PM                MOTOR VEHICLE COLLISION  21.280513 -157.784640
# 4329  5:03:05 PM  TRAFFIC NUISANCE OR PARKING VIOLATION  21.472379 -158.010142

# %%
df_subset.to_pickle('master_location.pkl')

# %%
df_subset['hour'] = df_subset.date.apply(lambda d: d.hour) 
df_subset.head()
# Out:
#                      address      area                date         location  \
# 4333        174X MAHANI LOOP    KALIHI 2016-11-07 16:51:13
# 4332  KAWAIAHAO ST&SOUTH; ST  HONOLULU 2016-11-07 16:54:37
# 4331        316X HARDING AVE   KAIMUKI 2016-11-07 16:56:45
# 4330   KILAUEA AVE&MALIA; ST   WAIALAE 2016-11-07 17:02:02
# 4329         H2N WAHIAWA OFF  MILILANI 2016-11-07 17:03:05  H2N WAHIAWA OFF
#
#             time                                   type   latitude  \
# 4333  4:51:13 PM                MOTOR VEHICLE COLLISION  21.351571
# 4332  4:54:37 PM        MOTOR VEHICLE COLLISION - TOWED  21.302850
# 4331  4:56:45 PM                MOTOR VEHICLE COLLISION  21.286176
# 4330  5:02:02 PM                MOTOR VEHICLE COLLISION  21.280513
# 4329  5:03:05 PM  TRAFFIC NUISANCE OR PARKING VIOLATION  21.472379
#
#        longitude  hour
# 4333 -157.857829    16
# 4332 -157.857111    16
# 4331 -157.809424    16
# 4330 -157.784640    17
# 4329 -158.010142    17

# %%
df_subset['day'] = df_subset.date.apply(lambda d: d.day)

# %%
set(df_subset.type)
# Out:
# {'HAZARDOUS DRIVER',
#  'MOTOR VEHICLE COLLISION',
#  'MOTOR VEHICLE COLLISION - TOWED',
#  'STALLED/HAZARDOUS VEHICLE',
#  'TRAFFIC INCIDENT - NO COLLISION',
#  'TRAFFIC NUISANCE OR PARKING VIOLATION',
#  'TRAFFIC SIGNAL PROBLEM'}

# %%
df_subset['hour'].hist(bins=24)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 233

# %%
df_subset['date'].plot()
